# %% [markdown]
# # This is the main notebook clustering train states using infomap
# - infomap has been the clustering algo used as Louvain seems to miss a lot of the structure of directed graphs
# - The results show infomap is able to identify sleep structure using purely graph theoretical concepts (no actual understanding of sleep)
# - For any questions, get in contact with Andrei R.-M.

# %%
import re
import pandas as pd
import os
import sys
module_path = os.path.abspath(os.path.join('..'))  # to add the helper functions on the path
if module_path not in sys.path:
    sys.path.append(module_path)
    
from utils import (get_states_sequence_from_df, get_state_sleep_stage_relationship, get_manual_sleep_stage_mapping, 
get_activation_pattern_train_state_mapping, simplify_states_sequence, build_transition_dict, build_transition_graph, 
get_state_frequency, get_communities_mapping_from_node_mapping, produce_exit_pattern)

from sleep_slab_plotting import draw_simplified_sleep_slab, draw_all_sleep_slabs

from transition_graph_plotting import (draw_transition_graph, draw_transition_graph_with_pie_chart_nodes, draw_community_pie_chart_nodes, 
draw_community_transition_graph, draw_activation_pattern_difference_with_pie_chart_nodes)

# %%
# Here we deal with reading infomation from files.
# In the future, the file format might change. Essentially we care about getting the states produces by the mcRBM in sequential order

STATES_SEQUENCE_FILE = "Epochs_OSBasic_AllRats_NoArtifactTs_Timeorder.txt"  # 'Epochs_OSBasic_Rat3_AllSDs_NoArtifact&TS_timeOrder.txt'  # example for file (living in the data folder)

def get_df_from_states_file(file_name, rename_missing_train_states=True, folder_path='data'):
    """This function assumes the data is saved in a very particular format. It can be changed accordingly to suit other formats"""
    latent_states_sequence = []
    with open(f'{folder_path}/{file_name}', 'r') as file:
        lines = file.readlines()
        data_lines = [line for line in lines if not line.startswith('---') and not line.startswith('ID')]
        parsed_data = [re.split(r'\s{2,}|\t+', line.strip()) for line in data_lines if line.strip]
        df = pd.DataFrame(parsed_data, columns=['id', 'binary_pattern', 'train_state', 'sleep_stage'])
        df['train_state'] = df['train_state'].astype(int)
        df.drop(columns=['id'], inplace=True)
        if rename_missing_train_states and min(df['train_state']) < 0:  # this replaces train_states which initially came with value -1 with new values (above 100 to not conflict with already existing train_states)
            max_known_train_state = 96
            assert max(df['train_state']) <= max_known_train_state, ' Got more train states in the initial dataset than expected.'
            print(f'Got some train states unencountered before. Renaming them with numbers above {max_known_train_state}')
            target_codes = df.loc[df['train_state'] == -1, 'binary_pattern'].unique()
            mapping = {code: i for i, code in enumerate(target_codes, start=max_known_train_state+1)}
            df['train_state'] = df.apply(lambda row: mapping.get(row['binary_pattern'], row['train_state']), axis=1)
    return df

df = get_df_from_states_file(STATES_SEQUENCE_FILE)
df.head()
# Out:
#   binary_pattern  train_state sleep_stage
# 0     1101101001           66        Wake
# 1     1101101001           66        Wake
# 2     1011101001           52        Wake
# 3     1011101001           52        Wake
# 4     1011101001           52        Wake

# %%
# Here we format the data into multiple formats to later use for our analysis 

latent_states_sequence = get_states_sequence_from_df(df)  # raw sequence of train states in sequential order
sleep_stage_mapping_frequency = get_state_sleep_stage_relationship(df)  # what each train state has been manually labelled as 
manually_labelled_dict = get_manual_sleep_stage_mapping(df)  # assign one sleep stage to each train state based on the most common manual label
state_to_pattern_dict = get_activation_pattern_train_state_mapping(df)  # the mapping between train states and binary activation patterns

simplified_states_sequence = simplify_states_sequence(latent_states_sequence)  # sequence of train states in compressed format (our main object to work from now on)
sleep_stages = simplify_states_sequence(get_states_sequence_from_df(df, 'sleep_stage'))  # the epochs sequence using only the manual labels (instead of train states)
transition_dict = build_transition_dict(simplified_states_sequence)  # the states transitions represented in dict form
transition_graph = build_transition_graph(transition_dict)  # create a graph object based on the transition dict

# %%
# This is the backbone of the project: using infomap to cluster the nodes in the transition graph
# There are 2 main ways to use infomap: using the raw edge weights (the weight of an edge would be the number of times that transition happens)
# or percentage weights (all weights of edges coming out of each node add up to 1 - representing the corresponding transition chances from each node).
# Empirically, I found the second application (use_raw_edge_weights=False) to give more robust results.

from infomap import Infomap  
# this package was a pain to install due to C++ dependencies. I do not wish it on my worst enemy. I used ChatGPT to help me through the process

def apply_infomap(simplified_states_sequence, use_raw_edge_weights=True, include_self_loops=False):
    """Build a dictionary with the communities produced my infomap
    This is the trivial application of infomap and more complicated ones may be used in the future."""
    im = Infomap("--directed --two-level")
    transition_dict = build_transition_dict(simplified_states_sequence, include_self_loops=include_self_loops)
    for source, targets in transition_dict.items():
        total_flow = 1 if use_raw_edge_weights else sum(targets.values())
        for target, weight in targets.items():
            im.add_link(source, target, weight / total_flow)
    im.run()
    print(f'The associated infomap code length is {round(im.codelength, 2)}')  # the associated code length for the clustering. Feel free to ignore

    node_community_mapping = {}
    for node in im.tree:
        if node.is_leaf:
            module = node.module_id
            node_id = node.node_id
            node_community_mapping[node_id] = module  
    return node_community_mapping

node_community_mapping = apply_infomap(simplified_states_sequence, use_raw_edge_weights=False)  # the clustering produced by infomap
# Out:
# The associated infomap code length is 4.92

# %%
# Here are some experiments with multi-level infomap
# The idea is that you can do further subclustering, altho for the datasets I worked with, there wasn't much there.
# Feel free to ignore.

def hierarchical_infomap_testing(simplified_states_sequence, use_raw_edge_weights=True, include_self_loops=False):  
    im = Infomap("--directed")
    print(f'Number of nodes: {len(set(x[0] for x in simplified_states_sequence))}')
    transition_dict = build_transition_dict(simplified_states_sequence, include_self_loops=include_self_loops)
    for source, targets in transition_dict.items():
        total_flow = 1 if use_raw_edge_weights else sum(targets.values())
        for target, weight in targets.items():
            im.add_link(source, target, weight / total_flow)
    im.run()

    foo = set()
    for node in im.tree:
        if node.is_leaf:
            node_path = node.path[:2]
            foo.add(node_path)
    print(f'Number of big clusters: {len(set(x[0] for x in foo))}')
    print(f'Number of little clusters: {len(foo)}')

hierarchical_infomap_testing(simplified_states_sequence=simplified_states_sequence, 
                             use_raw_edge_weights=False, 
                             include_self_loops=False)
# Out:
# Number of nodes: 96
# Number of big clusters: 11
# Number of little clusters: 96

# %%
# Here we do some testing for plotting sleeb slabs (to visualise the initial data)

draw_all_sleep_slabs(simplified_states_sequence=simplified_states_sequence,
                    sleep_stages=sleep_stages,
                    node_community_mapping=node_community_mapping,
                    manually_labelled_dict=manually_labelled_dict,
                    # xlim=(15_000, 20_000) # in case you want to zoom in on a particular part of the slab
                    )

# %%
# Some aggregate functions to make applying the pipeline easier for quick analysis
# This is where the critical functions live

def get_high_level_overview_for_states_file(file_name, folder_path='data', min_edge_frequency=None, node_size_adjustment_factor=800, seed=None):
    """For now, I just add as much data as possible. Later on, I might improve/cut some of it"""
    df = get_df_from_states_file(file_name=file_name, folder_path=folder_path)
    #print(df.head())

    sleep_stages = simplify_states_sequence(get_states_sequence_from_df(df, 'sleep_stage'))
    stage_frequency = get_state_frequency(sleep_stages, transform_to_ratios=True)
    print('HIGH LEVEL STATS')
    for sleep_stage, ratio in stage_frequency.items():
        print(f'{sleep_stage}: {round(ratio * 100, 1)}%')
    
    draw_simplified_sleep_slab(sleep_stages, custom_title=f'Original Sleep Labels ({file_name})')  #, xlim=(290_000, 310_000))
    draw_transition_graph(simplified_states_sequence=sleep_stages, draw_raw_edge_weights=True, custom_title=f'Original Sleep Graph ({file_name})', seed=seed)
    # print(build_transition_dict(sleep_stages))

    simplified_states_sequence = simplify_states_sequence(get_states_sequence_from_df(df))
    sleep_stage_mapping_frequency = get_state_sleep_stage_relationship(df)
    draw_transition_graph_with_pie_chart_nodes(simplified_states_sequence=simplified_states_sequence, 
                                               sleep_stage_mapping_frequency=sleep_stage_mapping_frequency, 
                                               min_edge_frequency=min_edge_frequency,
                                               custom_title=f'Transition Graph of Latent States ({file_name})',
                                               node_size_adjustment_factor=node_size_adjustment_factor,
                                               seed=seed)
    
    manually_labelled_dict = get_manual_sleep_stage_mapping(df)
    # draw_transition_graph(simplified_states_sequence=simplified_states_sequence, community_mapping=manually_labelled_dict, seed=seed)


def apply_infomap_from_basic_stuff(simplified_states_sequence, sleep_stages, 
                                   sleep_stage_mapping_frequency, 
                                   use_raw_edge_weights=True, 
                                   include_self_loops=False, 
                                   min_edge_frequency=None,
                                   node_label_mapping=None, 
                                   node_size_adjustment_factor=800,
                                   draw_raw_edge_weights=True,
                                   seed=None):
    node_community_mapping = apply_infomap(simplified_states_sequence=simplified_states_sequence, 
                                           use_raw_edge_weights=use_raw_edge_weights, 
                                           include_self_loops=include_self_loops)

    draw_all_sleep_slabs(simplified_states_sequence=simplified_states_sequence, 
                         sleep_stages=sleep_stages, 
                         node_community_mapping=node_community_mapping)
    
    draw_transition_graph_with_pie_chart_nodes(simplified_states_sequence=simplified_states_sequence, 
                                               sleep_stage_mapping_frequency=sleep_stage_mapping_frequency,
                                               min_edge_frequency=min_edge_frequency,
                                               node_label_mapping=node_label_mapping,
                                               node_size_adjustment_factor=node_size_adjustment_factor,
                                               seed=seed)
    
    draw_transition_graph(simplified_states_sequence=simplified_states_sequence, 
                          community_mapping=node_community_mapping, 
                          min_edge_frequency=min_edge_frequency,
                          node_label_mapping=node_label_mapping, 
                          seed=seed)

    draw_community_pie_chart_nodes(node_community_mapping=node_community_mapping, sleep_stage_mapping_frequency=sleep_stage_mapping_frequency, 
                                   state_frequency=get_state_frequency(simplified_states_sequence))
    
    draw_community_transition_graph(simplified_states_sequence, node_community_mapping, draw_raw_edge_weights=draw_raw_edge_weights, seed=seed) 


def apply_infomap_from_file(file_name, folder_path='data', use_raw_edge_weights=True, include_self_loops=False, min_edge_frequency=None,
                            node_size_adjustment_factor=800, draw_raw_edge_weights=True, seed=None):
    """Draw the sleep plots resulting from applying infomap on the sequence of states in the file"""
    df = get_df_from_states_file(file_name=file_name, folder_path=folder_path)
    simplified_states_sequence = simplify_states_sequence(get_states_sequence_from_df(df))
    sleep_stages = simplify_states_sequence(get_states_sequence_from_df(df, 'sleep_stage'))
    sleep_stage_mapping_frequency = get_state_sleep_stage_relationship(df)
    
    apply_infomap_from_basic_stuff(simplified_states_sequence=simplified_states_sequence, 
                                   sleep_stages=sleep_stages,
                                   sleep_stage_mapping_frequency=sleep_stage_mapping_frequency,
                                   use_raw_edge_weights=use_raw_edge_weights,
                                   include_self_loops=include_self_loops,
                                   min_edge_frequency=min_edge_frequency,
                                   node_size_adjustment_factor=node_size_adjustment_factor,
                                   draw_raw_edge_weights=draw_raw_edge_weights,
                                   seed=seed)

    
# get_high_level_overview_for_states_file(STATES_SEQUENCE_FILE, seed=40)

# apply_infomap_from_basic_stuff(simplified_states_sequence=simplified_states_sequence,
#                                sleep_stages=sleep_stages,
#                                sleep_stage_mapping_frequency=sleep_stage_mapping_frequency, 
#                                use_raw_edge_weights=True,
#                                include_self_loops=False,
#                                node_label_mapping=None,
#                                seed=40
#                               )

# apply_infomap_from_file(STATES_SEQUENCE_FILE, use_raw_edge_weights=False, seed=40)  # "Epochs_OSBasic_Rat3_AllSDs_Artifact&TS_timeOrder.txt"  # STATES_SEQUENCE_FILE 

get_high_level_overview_for_states_file("Epochs_OSBasic_AllRats_NoArtifactTs_Timeorder.txt", node_size_adjustment_factor=600, seed=40)  # "Epochs_RGS14_AllRats_NoArtifactTs_Timeorder.txt"  # "Epochs_OSBasic_AllRats_NoArtifactTs_Timeorder.txt"
# Out:
# HIGH LEVEL STATS
# NREM: 47.2%
# Wake: 44.1%
# REM: 8.8%

# %%
# This is where the main result lies: the clustering produced by infomap divides the data into 11 clusters with clear delineation for REM.

apply_infomap_from_file("Epochs_OSBasic_AllRats_NoArtifactTs_Timeorder.txt", 
                        use_raw_edge_weights=False, include_self_loops=False,
                        node_size_adjustment_factor=600, draw_raw_edge_weights=False, seed=40)  # "Epochs_OSBasic_AllRats_NoArtifactTs_Timeorder.txt", # "Epochs_RGS14_AllRats_NoArtifactTs_Timeorder.txt"
# Out:
# The associated infomap code length is 4.92

# %%
# Here we try running some analysis on entry/exit patterns. Once a random walk exits a cluster, what nodes does it go to?
# The idea is to see for example if REM is mostly followed by very particular latent states (suggesting the existence of intermediary states)

def produce_entry_pattern(node_community, transition_dict, transform_to_ratios=False):
    """Return 2 dictionaries: one for exit nodes outside the community and one for entry nodes inside the community.
    This function looks at random walks entering the community and remembering the associated nodes"""
    #todo find better wording, var names as this function might look confusing to someone also looking at produce_exit_pattern()

    entry_dict, exit_dict = {}, {}
    for node, transitions in transition_dict.items():
        if node not in node_community:  # we only care about transitions coming from outside the community
            for transition_node, freq in transitions.items():
                if transition_node in node_community:  # we only care about transitions going inside the community
                    exit_dict[node] = exit_dict.get(node, 0) + freq
                    entry_dict[transition_node] = entry_dict.get(transition_node, 0) + freq

    entry_dict = dict(sorted(entry_dict.items(), key=lambda item: item[1], reverse=True))
    exit_dict = dict(sorted(exit_dict.items(), key=lambda item: item[1], reverse=True))
    if transform_to_ratios:
        exit_dict = {node: freq / sum(exit_dict.values()) for node, freq in exit_dict.items()}
        entry_dict = {node: freq / sum(entry_dict.values()) for node, freq in entry_dict.items()}
    return exit_dict, entry_dict

communities_dict = get_communities_mapping_from_node_mapping(node_community_mapping)
nodes_subset = communities_dict[4]

# produce_entry_pattern(node_community=communities_dict[4], transition_dict=transition_dict, transform_to_ratios=True)

draw_transition_graph_with_pie_chart_nodes(simplified_states_sequence=simplified_states_sequence, 
                                           sleep_stage_mapping_frequency=sleep_stage_mapping_frequency, 
                                           min_edge_frequency=10,
                                           node_community=nodes_subset, 
                                           node_size_adjustment_factor=50)

# produce_exit_pattern(node_community=nodes_subset, transition_dict=transition_dict, transform_to_ratios=True)

# %%
# Here I'll think more of unidirectional edges and if that can be used to find bridges between communities. This was WIP

#TODO: finish this function
def draw_unidirectional_edges_transition_graph_with_pie_chart_nodes(simplified_states_sequence, sleep_stage_mapping_frequency, min_edge_frequency=None,
                                               draw_raw_edge_weights=False, edge_weight_font_size=7, node_label_mapping=None, 
                                               custom_title=None, node_size_adjustment_factor=800, seed=None):
    transition_dict = build_transition_dict(simplified_states_sequence)
    G = build_transition_graph(transition_dict, min_edge_frequency=min_edge_frequency)

    pos = nx.spring_layout(G, seed=seed)
    
    plt.figure(figsize=(15, 10))
    plt.axis('equal')
    ax = plt.gca()

    node_sizes_dict = get_node_sizes(simplified_states_sequence)
    node_sizes = [node_sizes_dict[node] for node in G.nodes()]
    
    edge_weights = [G[u][v]['weight'] for u, v in G.edges()]

    sleep_stages = list({k for inner in sleep_stage_mapping_frequency.values() for k in inner})
    community_to_colour = assign_colours_to_communities(sleep_stages)

    for node in G.nodes():
        centre = pos[node]
        size = node_sizes_dict[node] ** 0.5 / node_size_adjustment_factor

        freqs = sleep_stage_mapping_frequency[node]
        total = sum(freqs.values())
        proportions = [v / total for v in freqs.values()]
        labels = list(freqs.keys())
    
        colours = [community_to_colour[label] for label in labels] 
    
        draw_pie_node(ax, centre, radius=size, proportions=proportions, colours=colours)

    nx.draw_networkx_edges(
        G, pos,
        edgelist=G.edges(),
        edge_color='gray',
        width=[w * 3 for w in edge_weights],
        arrows=True,
        connectionstyle='arc3,rad=0.1'
    )
    
    if draw_raw_edge_weights:
        G_raw = build_transition_graph(transition_dict=transition_dict, use_raw_edge_weights=True, min_edge_frequency=min_edge_frequency)
        nx.draw_networkx_edge_labels(G, pos, edge_labels={(u, v): int(G_raw[u][v]['weight']) for u, v in G.edges()}, font_size=edge_weight_font_size, label_pos=0.2, rotate=False)

    if node_label_mapping:
        labels = {node: node_label_mapping.get(node, node) for node in G.nodes()}
    else:
        labels = {node: node for node in G.nodes()}
    nx.draw_networkx_labels(G, pos, labels=labels)

    legend_handles = [patches.Patch(color=color, label=community) for community, color in community_to_colour.items()]
    plt.legend(handles=legend_handles, title="Communities", loc="upper right")

    if custom_title is not None:
        plt.title(custom_title)
    elif node_community is not None:
        title = 'Node Community Exit Pattern'
    else:
        title = 'Transition Graph of Latent States'
    if min_edge_frequency is not None:
        title += f' (min edge frequency {min_edge_frequency})'
    plt.title(title)
    plt.axis('off')
    plt.show()

def build_edges_dict(transition_dict):
    edges_dict = {}
    for node, transition_nodes in transition_dict.items():
        for t_node, freq in transition_nodes.items():
            edges_dict[(node, t_node)] = freq
    
    final_dict = {}
    for (node1, node2), freq in edges_dict.items():
        freq2 = edges_dict.get((node2, node1), 0)
        if freq2 < freq:
            final_dict[(node1, node2)] = [freq, freq2]
            final_dict[(node1, node2)].append(freq2 / freq)
    return final_dict

edges_dict = sorted(build_edges_dict(transition_dict).items(), key=lambda x: x[1][0], reverse=True)
[x for x in edges_dict if x[1][2] < 1 / 3]
# Out:
# [((95, 82), [325, 92, 0.28307692307692306]),
#  ((82, 83), [166, 35, 0.21084337349397592]),
#  ((18, 63), [99, 31, 0.31313131313131315]),
#  ((71, 63), [98, 32, 0.32653061224489793]),
#  ((95, 83), [86, 8, 0.09302325581395349]),
#  ((84, 85), [74, 20, 0.2702702702702703]),
#  ((66, 40), [58, 18, 0.3103448275862069]),
#  ((95, 85), [55, 2, 0.03636363636363636]),
#  ((39, 5), [54, 13, 0.24074074074074073]),
#  ((65, 13), [49, 11, 0.22448979591836735]),
#  ((82, 85), [48, 4, 0.08333333333333333]),
#  ((5, 16), [37, 4, 0.10810810810810811]),
#  ((69, 95), [36, 4, 0.1111111111111111]),
#  ((2, 13), [35, 7, 0.2]),
#  ((74, 68), [33, 9, 0.2727272727272727]),
#  ((17, 95), [31, 2, 0.06451612903225806]),
#  ((63, 36), [26, 5, 0.19230769230769232]),
#  ((64, 36), [25, 7, 0.28]),
#  ((89, 78), [24, 6, 0.25]),
#  ((69, 18), [22, 7, 0.3181818181818182]),
#  ((61, 38), [21, 4, 0.19047619047619047]),
#  ((17, 26), [21, 3, 0.14285714285714285]),
#  ((39, 16), [20, 4, 0.2]),
# ...

# %%
# Here I'll think more of the transitions between binary activation patterns.
# The first thing I want to know is how often do you encounter "rough" transitions (transitions where the Hamming distance between neighbouring states is high)

# state_to_pattern_dict
# transition_dict

distance_dict = {}
for node, targets in transition_dict.items():
    for transition_node, freq in targets.items():
        d = compute_distance_between_states(node, transition_node, state_to_pattern_dict)
        if node in distance_dict:
            distance_dict[node][d] = distance_dict[node].get(d, 0) + freq
        else:
            distance_dict[node] = {d: freq}
    distance_dict[node] = dict(sorted(distance_dict[node].items(), key=lambda item: item[0]))
            
distance_dict


edges_dict = {}
for node, transition_nodes in transition_dict.items():
    for t_node, freq in transition_nodes.items():
        edges_dict[(node, t_node)] = (freq, compute_distance_between_states(node, t_node, state_to_pattern_dict))

edges_dict = dict(sorted(edges_dict.items(), key=lambda item: (item[1][1], -item[1][0])))
edges_dict

transition_diff_dict = {}
for freq, diff in edges_dict.values():
    transition_diff_dict[diff] = transition_diff_dict.get(diff, 0) + freq

transition_diff_dict
edges_dict

# Here I'll try to build a function that plots a set of nodes and the difference in the activation patterns

# draw_activation_pattern_difference_with_pie_chart_nodes(simplified_states_sequence=simplified_states_sequence,
#                                                         sleep_stage_mapping_frequency=sleep_stage_mapping_frequency,
#                                                         nodes_subset=communities_dict[4],
#                                                         min_edge_frequency=5,
#                                                         node_size_adjustment_factor=600,
#                                                         seed=40
#                                                        )
# Out:
# {(40, 38): (1387, 1),
#  (38, 40): (1368, 1),
#  (38, 52): (1350, 1),
#  (52, 38): (1332, 1),
#  (36, 40): (888, 1),
#  (40, 36): (833, 1),
#  (18, 17): (794, 1),
#  (17, 18): (753, 1),
#  (18, 12): (742, 1),
#  (20, 19): (716, 1),
#  (63, 14): (709, 1),
#  (14, 63): (694, 1),
#  (38, 37): (693, 1),
#  (35, 36): (678, 1),
#  (12, 18): (664, 1),
#  (36, 35): (662, 1),
#  (14, 18): (648, 1),
#  (19, 20): (609, 1),
#  (65, 73): (607, 1),
#  (40, 39): (604, 1),
#  (73, 19): (580, 1),
#  (35, 39): (562, 1),
#  (39, 35): (551, 1),
#  (19, 73): (543, 1),
#  (63, 35): (543, 1),
#  (19, 17): (530, 1),
#  (67, 65): (528, 1),
#  (65, 67): (523, 1),
#  (73, 95): (516, 1),
#  (90, 66): (513, 1),
#  (37, 38): (501, 1),
#  (18, 14): (500, 1),
#  (66, 65): (497, 1),
#  (14, 10): (497, 1),
#  (37, 65): (496, 1),
#  (85, 83): (493, 1),
#  (17, 19): (490, 1),
#  (34, 38): (483, 1),
#  (35, 33): (472, 1),
#  (33, 35): (469, 1),
#  (65, 61): (460, 1),
#  (78, 90): (456, 1),
#  (12, 11): (452, 1),
# ...

# %%
# Here I'll try spreading the nodes based on their sleep stage mapping frequency

def foobar(simplified_states_sequence, sleep_stage_mapping_frequency,
                                               draw_raw_edge_weights=False, edge_weight_font_size=7, node_label_mapping=None, 
                                               custom_title=None, seed=None):
    transition_dict = build_transition_dict(simplified_states_sequence)
    G = build_transition_graph(transition_dict)

    sleep_stages = list({k for inner in sleep_stage_mapping_frequency.values() for k in inner})
    stage_to_angle = {stage: 2 * np.pi * i / len(sleep_stages) for i, stage in enumerate(sleep_stages)}
    radius = 1
    stage_to_centre = {stage: (2 * radius * np.cos(theta), radius * np.sin(theta)) for stage, theta in stage_to_angle.items()}
    pos_init = {}
    rng = np.random.default_rng(seed)
    for node, freqs in sleep_stage_mapping_frequency.items():
        total = sum(freqs.values())
        x = sum((freqs[stage] / total) * stage_to_centre[stage][0] for stage in freqs)
        y = sum((freqs[stage] / total) * stage_to_centre[stage][1] for stage in freqs)
        jitter = 0.2 * radius
        x += rng.uniform(-jitter, jitter)
        y += rng.uniform(-jitter, jitter)
        pos_init[node] = np.array([x, y])
    
    pos = nx.spring_layout(G, pos=pos_init, seed=seed, iterations=3)
    
    plt.figure(figsize=(15, 10))
    plt.axis('equal')
    ax = plt.gca()

    node_sizes_dict = get_node_sizes(simplified_states_sequence)
    node_sizes = [node_sizes_dict[node] for node in G.nodes()]
    
    edge_weights = [G[u][v]['weight'] for u, v in G.edges()]

    community_to_colour = assign_colours_to_communities(sleep_stages)

    all_x = [p[0] for p in pos.values()]
    all_y = [p[1] for p in pos.values()]
    span = max(max(all_x) - min(all_x), max(all_y) - min(all_y))
    max_radius = span * 0.03
    max_size = max(node_sizes_dict.values())
    node_size_adjustment_factor = (max_size ** 0.5) / max_radius
    
    for node in G.nodes():
        centre = pos[node]
        size = node_sizes_dict[node] ** 0.5 / node_size_adjustment_factor

        freqs = sleep_stage_mapping_frequency[node]
        total = sum(freqs.values())
        proportions = [v / total for v in freqs.values()]
        labels = list(freqs.keys())
    
        colours = [community_to_colour[label] for label in labels] 
    
        draw_pie_node(ax, centre, radius=size, proportions=proportions, colours=colours)

    nx.draw_networkx_edges(
        G, pos,
        edgelist=G.edges(),
        edge_color='gray',
        width=[w * 3 for w in edge_weights],
        arrows=True,
        connectionstyle='arc3,rad=0.1'
    )
    
    if draw_raw_edge_weights:
        G_raw = build_transition_graph(transition_dict=transition_dict, use_raw_edge_weights=True)
        nx.draw_networkx_edge_labels(G, pos, edge_labels={(u, v): int(G_raw[u][v]['weight']) for u, v in G.edges()}, font_size=edge_weight_font_size, label_pos=0.2, rotate=False)

    if node_label_mapping:
        labels = {node: node_label_mapping.get(node, node) for node in G.nodes()}
    else:
        labels = {node: node for node in G.nodes()}
    nx.draw_networkx_labels(G, pos, labels=labels)

    legend_handles = [patches.Patch(color=color, label=community) for community, color in community_to_colour.items()]
    plt.legend(handles=legend_handles, title="Communities", loc="upper right")

    if custom_title is not None:
        plt.title(custom_title)
    else:
        plt.title('Transition Graph of Latent States')
    plt.axis('off')
    plt.show()


foobar(simplified_states_sequence=simplified_states_sequence, sleep_stage_mapping_frequency=sleep_stage_mapping_frequency, seed=41)
