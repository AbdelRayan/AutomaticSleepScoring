# %% [markdown]
# # Load the datasets
#
# The path to dataset directory and patterns to search in those directories for the HPC, PFC recordings are in loaded from the config file.

# %%
from phasic_tonic.detect_phasic import detect_phasic
from phasic_tonic.DatasetLoader import DatasetLoader
from phasic_tonic.helper import get_metadata
from phasic_tonic.runtime_logger import logger_setup
from phasic_tonic.utils import get_sequences

import numpy as np
import pandas as pd
import pynapple as nap
import yasa

from tqdm.auto import tqdm
from scipy.io import loadmat
from mne.filter import resample

fs_cbd = 2500
fs_os = 2500
fs_rgs = 1000

targetFs = 500
n_down_cbd = fs_cbd/targetFs
n_down_rgs = fs_rgs/targetFs
n_down_os = fs_os/targetFs

logger = logger_setup()

CONFIG_DIR = "/home/nero/phasic_tonic/data/dataset_loading.yaml"

Datasets = DatasetLoader(CONFIG_DIR)
mapped_datasets = Datasets.load_datasets()

def preprocess(signal: np.ndarray, n_down: int, target_fs=500) -> np.ndarray:
    """Downsample and remove artifacts."""
    
    logger.debug("STARTED: Resampling to 500 Hz.")
    # Downsample to 500 Hz
    data = resample(signal, down=n_down, method='fft', npad='auto')
    logger.debug("FINISHED: Resampling to 500 Hz.")
    logger.debug("Resampled: {0} -> {1}.".format(str(signal.shape), str(data.shape)))
    
    logger.debug("STARTED: Remove artifacts.")
    # Remove artifacts
    art_std, _ = yasa.art_detect(data, target_fs , window=1, method='std', threshold=4)
    art_up = yasa.hypno_upsample_to_data(art_std, 1, data, target_fs)
    data[art_up] = 0
    logger.debug("FINISHED: Remove artifacts.")
        
    data -= data.mean()
    return data

def get_start_end(hypno: np.ndarray, sleep_state_id: int):
    """Convert sleep states into lists of start and end time indices."""
    seq = get_sequences(np.where(hypno == sleep_state_id)[0])
    start = []
    end = []
    for s, e in seq:
        start.append(s)
        end.append(e)
    return (start, end)

# %% [markdown]
# Check the number of loaded recordings

# %%
cbd_cnt = 0
rgs_cnt = 0
os_cnt = 0

# Count recordings belonging to CBD dataset
for name in mapped_datasets:
    metadata = get_metadata(name)
    if metadata['treatment'] == 0 or metadata['treatment'] == 1:
        cbd_cnt += 1
    elif metadata['treatment'] == 2 or metadata['treatment'] == 3:
        rgs_cnt += 1
    elif metadata['treatment'] == 4:
        os_cnt += 1

assert cbd_cnt == 170
assert rgs_cnt == 159
assert os_cnt == 210

# %% [markdown]
# # Waveform analysis

# %%
import emd
from neurodsp.filt import filter_signal

def compute_range(x):
    return x.max() - x.min()

def asc2desc(x):
    """Ascending to Descending ratio ( A / A+D )."""
    pt = emd.cycles.cf_peak_sample(x, interp=True)
    tt = emd.cycles.cf_trough_sample(x, interp=True)
    if (pt is None) or (tt is None):
        return np.nan
    asc = pt + (len(x) - tt)
    #desc = tt - pt
    return asc / len(x)

def peak2trough(x):
    """Peak to trough ratio ( P / P+T )."""
    des = emd.cycles.cf_descending_zero_sample(x, interp=True)
    if des is None:
        return np.nan
    return des / len(x)

def compute_cycles(signal, fs, metadata):
    signal = filter_signal(signal, fs, 'bandpass', (5,12), remove_edges=False)
    # Perform EMD and compute cycle metrics
    IP, IF, IA = emd.spectra.frequency_transform(signal, fs, 'hilbert', smooth_phase=3)
    C = emd.cycles.Cycles(IP.flatten())
    print("Detected cycles before extraction:")
    print(C)

    # Compute cycle metrics
    C.compute_cycle_metric('start_sample', np.arange(len(C.cycle_vect)), emd.cycles.cf_start_value)
    C.compute_cycle_metric('stop_sample', signal, emd.cycles.cf_end_value)
    C.compute_cycle_metric('peak_sample', signal, emd.cycles.cf_peak_sample)
    C.compute_cycle_metric('desc_sample', signal, emd.cycles.cf_descending_zero_sample)
    C.compute_cycle_metric('trough_sample', signal, emd.cycles.cf_trough_sample)
    C.compute_cycle_metric('duration_samples', signal, len)
    C.compute_cycle_metric('max_amp', IA, np.max)
    C.compute_cycle_metric('mean_if', IF, np.mean)
    C.compute_cycle_metric('max_if', IF, np.max)
    C.compute_cycle_metric('range_if', IF, compute_range)  # Make sure 'compute_range' is defined
    C.compute_cycle_metric('asc2desc', signal, asc2desc)  # Make sure 'asc2desc' is defined
    C.compute_cycle_metric('peak2trough', signal, peak2trough)  # Make sure 'peak2trough' is defined

    print('\nFinished computing the cycles metrics\n')

    # Extract a subset of the cycles
    amp_thresh = np.percentile(IA, 25)
    lo_freq_duration = fs / 5
    hi_freq_duration = fs / 12
    conditions = ['is_good==1',
                  f'duration_samples<{lo_freq_duration}',
                  f'duration_samples>{hi_freq_duration}',
                  f'max_amp>{amp_thresh}']

    print("Cycles after extraction:")
    df_emd = C.get_metric_dataframe(conditions=conditions)
    print(f'{len(df_emd)}')

    #Add the metadata
    df_emd["rat"]       = metadata["rat_id"]
    df_emd["study_day"] = metadata["study_day"]
    df_emd["condition"] = metadata["condition"]
    df_emd["treatment"] = metadata["treatment"]
    df_emd["trial_num"] = metadata["trial_num"]
    df_emd["state"]     = metadata["state"]
    
    start, end = metadata["interval"]
    df_emd["start"] = start
    df_emd["end"] = end

    return df_emd

# %% [markdown]
# # Loop through the dataset

# %%
combined = []

with tqdm(mapped_datasets) as mapped_tqdm:
    for name in mapped_tqdm:
        metadata = get_metadata(name)
        mapped_tqdm.set_postfix_str(name)
        states_fname, hpc_fname, pfc_fname = mapped_datasets[name]
        logger.debug("Loading: {0}".format(name))

        if metadata["treatment"] == 0 or metadata["treatment"] == 1:
            n_down = n_down_cbd
        elif metadata["treatment"] == 2 or metadata["treatment"] == 3:
            n_down = n_down_rgs
        elif metadata["treatment"] == 4:
            n_down = n_down_os
        
        # Load the LFP data
        lfpHPC = loadmat(hpc_fname)['HPC'].flatten()
        # lfpPFC = loadmat(pfc_fname)['PFC'].flatten()

        # Load the states
        hypno = loadmat(states_fname)['states'].flatten()
        
        # Skip if no REM epoch is detected
        if(not (np.any(hypno == 5))):
            logger.debug("No REM detected. Skipping.")
            continue
        elif(np.sum(np.diff(get_sequences(np.where(hypno == 5)[0]))) < 10):
            logger.debug("No REM longer than 10s. Skipping.")
            continue

        # Create Pynapple IntervalSet        
        start, end = get_start_end(hypno=hypno, sleep_state_id=5)
        rem_interval = nap.IntervalSet(start=start, end=end)
        #rem_interval = rem_interval.drop_short_intervals(threshold=10, time_units='s')
        
        # Create TsdFrame for HPC and PFC signals
        fs = n_down*targetFs
        t = np.arange(0, len(lfpHPC)/fs, 1/fs)
        lfp = nap.Tsd(t=t, d=lfpHPC)
        
        # Detect phasic intervals
        lfpHPC_down = preprocess(lfpHPC, n_down)
        phREM = detect_phasic(lfpHPC_down, hypno, targetFs)

        # Create phasic REM IntervalSet
        start, end = [], []
        for rem_idx in phREM:
            for s, e in phREM[rem_idx]:
                start.append(s/targetFs)
                end.append(e/targetFs)
        phasic_interval = nap.IntervalSet(start, end)
        tonic_interval = rem_interval.set_diff(phasic_interval)

        phasic_interval = phasic_interval.drop_short_intervals(0.6)
        tonic_interval = tonic_interval.drop_short_intervals(0.6)
        
        #Compute waveform dynamics for each intervals
        metadata['state'] = 'phasic'
        for i in range(len(phasic_interval)):
            metadata['interval'] = (phasic_interval[i]['start'].item(), phasic_interval[i]['end'].item())
            df_emd = compute_cycles(lfp.restrict(phasic_interval[i]).to_numpy(), lfp.rate, metadata)
            combined.append(df_emd)
            
        metadata['state'] = 'tonic'
        for i in range(len(tonic_interval)):
            metadata['interval'] = (tonic_interval[i]['start'].item(), tonic_interval[i]['end'].item())
            df_emd = compute_cycles(lfp.restrict(tonic_interval[i]).to_numpy(), lfp.rate, metadata)
            combined.append(df_emd)
# Out:
#   0%|          | 0/539 [00:00<?, ?it/s]
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (17 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 14
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (14 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 12
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (27 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 23
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (30 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 24
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (366 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 309
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (239 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 210
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (341 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 292
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (162 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 134
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (11 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 8
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (324 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 279
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (21 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 17
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (17 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 14
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (10 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (17 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 14
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (11 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (41 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 36
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (16 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 12
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (12 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 10
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (23 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 16
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (16 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 12
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (69 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 55
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (84 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 73
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (39 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 33
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (23 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 19
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (400 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 349
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (116 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 100
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (91 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 73
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (159 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 131
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (19 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 16
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (480 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 417
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (135 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 118
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (412 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 357
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (615 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 532
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (239 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 200
# /tmp/ipykernel_106440/84685924.py:34: UserWarning: Some epochs have no duration
#   rem_interval = nap.IntervalSet(start=start, end=end)
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (16 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 14
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (10 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (16 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 12
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (45 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 33
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (14 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 11
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (10 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 8
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (413 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 346
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (44 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 40
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (365 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 319
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (99 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 83
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (231 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 199
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (49 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 43
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (237 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 200
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (73 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 62
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (14 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 12
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (508 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 444
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (316 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 282
# /tmp/ipykernel_106440/84685924.py:34: UserWarning: Some epochs have no duration
#   rem_interval = nap.IntervalSet(start=start, end=end)
# /tmp/ipykernel_106440/84685924.py:52: UserWarning: end is not sorted. Sorting it.
#   phasic_interval = nap.IntervalSet(start, end)
# /tmp/ipykernel_106440/84685924.py:52: UserWarning: Some ends precede the relative start. Dropping them!
#   phasic_interval = nap.IntervalSet(start, end)
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (11 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 8
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (11 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 9
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (12 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 9
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (11 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 9
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (9 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 6
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (41 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 32
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (11 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 9
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (17 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 15
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (10 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (12 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 8
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (16 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 13
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (461 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 406
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (227 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 199
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (142 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 122
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (16 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 12
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (287 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 256
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (351 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 313
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (98 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 89
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (502 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 451
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (547 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 423
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (365 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 301
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (612 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 539
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (583 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 506
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (203 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 177
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (231 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 204
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (266 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 233
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (271 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 243
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (67 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 54
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (8 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 6
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (15 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 11
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (211 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 180
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (20 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 16
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (315 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 273
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (785 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 667
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (21 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 16
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (29 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 25
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (18 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 14
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (11 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 8
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (16 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 11
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (14 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 11
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (23 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 20
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (18 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 15
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (12 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 10
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (11 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 8
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (18 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 15
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (19 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 15
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (16 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 13
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (15 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 11
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (23 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 18
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (13 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 11
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (10 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (16 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 12
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (16 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 13
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (16 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 13
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (13 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 10
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (10 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (16 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 12
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (12 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 9
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (239 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 210
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (67 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 56
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (34 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 30
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (165 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 145
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (448 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 381
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (56 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 45
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (69 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 57
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (66 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 54
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (364 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 320
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (130 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 114
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (191 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 162
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (315 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 271
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (228 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 197
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (79 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 67
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (1318 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 1112
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (220 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 189
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (653 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 568
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (31 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 25
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (40 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 34
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (14 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 10
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (466 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 416
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (167 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 144
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (51 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 44
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (208 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 181
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (46 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 41
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (10 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 8
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (225 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 196
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (286 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 245
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (55 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 47
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (12 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 10
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (68 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 57
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (11 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 9
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (13 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 10
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (17 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 13
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (27 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 21
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (286 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 245
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (172 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 142
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (157 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 133
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (19 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 16
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (34 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 29
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (259 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 231
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (13 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 11
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (19 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 16
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (566 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 508
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (17 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 13
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (14 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 10
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (10 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 8
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (37 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 33
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (200 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 160
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (112 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 102
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (393 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 338
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (213 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 181
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (12 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 8
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (17 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 14
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (16 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 13
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (26 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 21
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (22 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 18
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (31 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 25
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (114 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 96
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (221 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 195
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (711 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 592
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (308 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 257
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (63 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 54
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (58 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 39
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (658 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 575
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (391 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 336
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (288 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 255
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (8 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 5
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (9 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 5
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (15 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 11
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (17 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 14
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (20 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 15
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (117 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 102
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (37 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 31
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (48 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 43
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (455 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 393
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (434 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 381
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (274 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 243
# /tmp/ipykernel_106440/84685924.py:34: UserWarning: Some epochs have no duration
#   rem_interval = nap.IntervalSet(start=start, end=end)
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (35 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 30
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (589 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 526
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (53 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 45
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (16 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 11
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (12 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 9
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (19 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 14
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (23 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 19
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (11 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (13 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 9
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (19 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 13
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (362 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 307
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (30 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 25
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (130 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 113
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (112 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 92
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (248 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 230
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (92 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 78
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (63 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 54
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (343 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 289
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (116 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 97
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (790 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 686
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (120 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 106
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (16 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 10
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (15 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 12
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (11 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 9
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (91 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 84
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (21 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 16
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (262 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 227
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (12 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 10
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (112 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 103
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (16 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 13
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (15 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 11
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (29 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 24
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (14 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 11
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (11 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 9
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (38 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 29
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (343 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 292
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (394 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 352
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (165 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 141
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (93 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 83
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (312 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 277
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (96 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 85
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (10 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 8
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (167 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 146
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (183 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 157
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (10 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (13 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 10
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (32 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 25
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (9 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (13 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 8
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (14 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 10
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (24 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 20
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (73 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 63
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (355 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 315
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (332 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 279
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (172 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 158
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (104 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 88
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (83 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 72
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (62 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 53
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (235 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 202
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (14 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 10
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (11 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 9
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (47 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 41
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (261 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 224
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (526 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 436
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (10 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (22 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 19
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (111 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 98
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (417 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 361
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (41 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 37
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (10 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 8
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (12 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 9
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (18 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 15
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (26 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 20
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (8 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 5
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (355 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 311
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (142 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 124
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (18 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 15
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (16 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 13
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (19 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 14
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (14 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 12
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (19 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 15
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (12 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 10
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (803 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 721
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (134 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 117
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (535 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 469
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (43 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 35
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (8 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 6
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (88 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 78
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (9 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 6
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (210 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 177
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (28 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 23
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (19 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 14
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (10 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 5
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (290 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 240
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (187 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 167
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (14 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 12
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (244 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 215
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (12 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 9
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (20 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 16
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (11 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 9
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (12 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 8
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (369 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 313
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (280 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 240
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (262 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 226
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (45 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 42
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (317 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 270
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (256 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 221
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (39 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 36
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (13 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 10
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (10 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 8
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (12 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 9
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (314 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 278
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (275 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 243
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (326 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 296
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (187 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 170
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (91 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 78
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (152 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 132
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (21 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 16
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (29 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# ...
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 10
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (29 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 25
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (16 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 14
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (11 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 8
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (22 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 18
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (23 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 20
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (11 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 8
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (17 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 14
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (37 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 33
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (10 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 8
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (12 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 9
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (10 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 8
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (33 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 26
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (11 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (30 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 26
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (10 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 8
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (17 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 15
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (25 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 22
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (17 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 14
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (14 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 12
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (29 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 24
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (23 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 19
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (10 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 8
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (16 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 13
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (20 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 17
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (9 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (535 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 448
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (531 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 470
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (104 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 92
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (141 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 126
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (252 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 210
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (698 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 613
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (112 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 102
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (44 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 36
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (16 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 13
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (351 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 314
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (256 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 220
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (19 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 17
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (831 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 686
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (63 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 60
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (206 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 181
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (387 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 355
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (150 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 126
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (155 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 143
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (34 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 26
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (79 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 74
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (152 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 133
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (175 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 155
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (16 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 14
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (39 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 33
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (230 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 206
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (280 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 244
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (41 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 36
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (187 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 170
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (286 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 258
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (103 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 90
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (247 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 215
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (95 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 75
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (299 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 264
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (180 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 155
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (51 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 45
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (965 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 825
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (38 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 33
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (218 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 182
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (179 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 155
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (255 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 223
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (11 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 8
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (276 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 239
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (448 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 405
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (150 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 131
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (92 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 71
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (130 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 120
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (146 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 129
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (11 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 8
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (605 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 522
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (98 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 81
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (809 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 721
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (11 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 9
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (17 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 13
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (17 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 14
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (14 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 11
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (19 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 16
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (16 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 12
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (24 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 21
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (10 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 7
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (15 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 12
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (31 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 25
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (18 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 15
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (75 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 60
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (671 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 583
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (169 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 145
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (318 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 279
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (27 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 22
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (542 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 482
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (56 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 54
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (453 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 401
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (207 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 181
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (52 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 44
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (51 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 31
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (187 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 161
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (30 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 25
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (328 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 289
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (41 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 33
# Detected cycles before extraction:
# <class 'emd.cycles.Cycles'> (77 cycles 1 metrics)
#
# Finished computing the cycles metrics
#
# Cycles after extraction:
# 64

# %%
df = pd.concat(combined)
df.to_csv("waveform.csv")
df
# Out:
#     index  is_good  start_sample  stop_sample peak_sample desc_sample  \
# 0       1        1            73    -1.344392   74.491578  139.778779
# 1       2        1           352    -4.894912   66.294021  136.284284
# 2       3        1           632    -1.225875   77.254592  159.772773
# 3       4        1           951    -3.933588    68.30965  140.175175
# 4       5        1          1215    -0.085567    67.03187  130.621622
# ..    ...      ...           ...          ...         ...         ...
# 59     64        1         20480    -3.214679   66.777418  132.354354
# 60     65        1         20750    -1.664917   69.948625   143.01001
# 61     66        1         21047    -0.954784   80.920309  159.489489
# 62     67        1         21362    -1.632400   71.040317  151.537538
# 63     69        1         21983    -1.890492   72.574241  141.387387
#
#    trough_sample  duration_samples     max_amp   mean_if  ...  asc2desc  \
# 0      210.05873               279  346.934723  8.965488  ...  0.514096
# 1     204.577186               280  344.788590  8.907574  ...  0.506132
# 2      241.03858               319  277.813918  7.853249  ...  0.486571
# 3     200.916937               264  265.904236  9.446615  ...  0.497700
# 4     204.962082               273  300.707967  9.187249  ...  0.494761
# ..           ...               ...         ...       ...  ...       ...
# 59    200.985124               270  255.230612  9.249035  ...  0.502934
# 60    218.015041               297  255.368559  8.423587  ...  0.501460
# 61    237.917172               315  275.369294  7.941124  ...  0.501597
# 62     222.76078               323  268.786136  7.725401  ...  0.530277
# 63    218.077854               303  212.227378  8.242622  ...  0.519790
#
#     peak2trough  rat  study_day  condition  treatment trial_num   state  \
# 0      0.500999    5          8         HC          0         3  phasic
# 1      0.486730    5          8         HC          0         3  phasic
# 2      0.500855    5          8         HC          0         3  phasic
# 3      0.530967    5          8         HC          0         3  phasic
# 4      0.478467    5          8         HC          0         3  phasic
# ..          ...  ...        ...        ...        ...       ...     ...
# 59     0.490201   11          4         OR          4         3   tonic
# 60     0.481515   11          4         OR          4         3   tonic
# 61     0.506316   11          4         OR          4         3   tonic
# 62     0.469156   11          4         OR          4         3   tonic
# 63     0.466625   11          4         OR          4         3   tonic
#
#        start      end
# 0   1379.984  1381.77
# 1   1379.984  1381.77
# 2   1379.984  1381.77
# 3   1379.984  1381.77
# 4   1379.984  1381.77
# ..       ...      ...
# 59  2016.230  2026.00
# 60  2016.230  2026.00
# 61  2016.230  2026.00
# 62  2016.230  2026.00
# 63  2016.230  2026.00
#
# [1023399 rows x 22 columns]

# %%
df['duration_samples'] = np.where(df['treatment'] <= 1, df['duration_samples']/2500, df['duration_samples'])
df['duration_samples'] = np.where(df['treatment'] == 4, df['duration_samples']/2500, df['duration_samples'])
df['duration_samples'] = np.where((df['treatment'] == 2) | (df['treatment'] == 3), df['duration_samples']/1000, df['duration_samples'])

# %%
df.to_csv("waveform.csv")

# %%
from phasic_tonic.utils import ensure_duration, get_segments
from scipy.signal import hilbert
from neurodsp.filt import filter_signal

eeg=lfpHPC_down
fs=targetFs
min_dur = 3
rem_idx = []

rem_seq = get_sequences(np.where(hypno == 5)[0])
for start, end in rem_seq:
    if ((end-start) > min_dur):
        rem_idx.append((start * fs, (end+1) * fs))

if len(rem_idx) == 0:
    raise ValueError("No REM epochs greater than min_dur.")

# get REM segments
rem_epochs = get_segments(rem_idx, eeg)

# Combine the REM indices with the corresponding downsampled segments
rem = {seq:seg for seq, seg in zip(rem_seq, rem_epochs)}

w1 = 5.0
w2 = 12.0
nfilt = 11
thr_dur = 900

trdiff_list = []
rem_eeg = np.array([])
eeg_seq = {}
sdiff_seq = {}
tridx_seq = {}
filt = np.ones((nfilt,))
filt = filt / filt.sum()

for idx in rem:
    start, end = idx

    epoch = rem[idx]
    epoch = filter_signal(epoch, fs, 'bandpass', (w1,w2), remove_edges=False)
    epoch = hilbert(epoch)

    inst_phase = np.angle(epoch)
    inst_amp = np.abs(epoch)

    # trough indices
    tridx = _detect_troughs(inst_phase, -3)

    # differences between troughs
    trdiff = np.diff(tridx)

    # smoothed trough differences
    sdiff_seq[idx] = np.convolve(trdiff, filt, 'same')

    # dict of trough differences for each REM period
    tridx_seq[idx] = tridx

    eeg_seq[idx] = inst_amp

    # differences between troughs
    trdiff_list += list(trdiff)

    # amplitude of the entire REM sleep
    rem_eeg = np.concatenate((rem_eeg, inst_amp)) 

trdiff = np.array(trdiff_list)
trdiff_sm = np.convolve(trdiff, filt, 'same')

# potential candidates for phasic REM:
# the smoothed difference between troughs is less than
# the 10th percentile:
thr1 = np.percentile(trdiff_sm, 10)
# the minimum smoothed difference in the candidate phREM is less than
# the 5th percentile
thr2 = np.percentile(trdiff_sm, 5)
# the peak amplitude is larger than the mean of the amplitude
# of the REM EEG.
thr3 = rem_eeg.mean()

phasicREM = {rem_idx:[] for rem_idx in rem.keys()}

for rem_idx in tridx_seq:
    rem_start, rem_end = rem_idx
    offset = rem_start * fs

    # trough indices
    tridx = tridx_seq[rem_idx]

    # smoothed trough interval
    sdiff = sdiff_seq[rem_idx]

    # amplitude of the REM epoch
    eegh = eeg_seq[rem_idx]

    # get the candidates for phREM
    cand_idx = np.where(sdiff <= thr1)[0]
    cand = get_sequences(cand_idx)

    for start, end in cand:
        # Duration of the candidate in milliseconds
        dur = ( (tridx[end]-tridx[start]+1)/fs ) * 1000
        if dur < thr_dur:
            continue # Failed Threshold 1
        
        min_sdiff = np.min(sdiff[start:end])
        if min_sdiff > thr2:
            continue # Failed Threshold 2
        
        mean_amp =  np.mean(eegh[tridx[start]:tridx[end]+1])
        if mean_amp < thr3:
            continue # Failed Threshold 3
        
        t_a = tridx[start] + offset
        t_b = np.min((tridx[end] + offset, rem_end * fs))
        
        ph_idx = (t_a, t_b+1)
        phasicREM[rem_idx].append(ph_idx)

def _detect_troughs(signal, thr):
    lidx  = np.where(signal[0:-2] > signal[1:-1])[0]
    ridx  = np.where(signal[1:-1] <= signal[2:])[0]
    thidx = np.where(signal[1:-1] < thr)[0]
    sidx = np.intersect1d(lidx, np.intersect1d(ridx, thidx))+1
    return sidx
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 48
#      45 inst_amp = np.abs(epoch)
#      47 # trough indices
# ---> 48 tridx = _detect_troughs(inst_phase, -3)
#      50 # differences between troughs
#      51 trdiff = np.diff(tridx)
#
# NameError: name '_detect_troughs' is not defined
