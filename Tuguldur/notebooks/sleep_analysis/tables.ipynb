# %%
import pandas as pd

df = pd.read_csv('/home/nero/phasic_tonic/data/analysis_output/segmented_posttrial5/sleep_states_per_trial.csv')
df2 = pd.read_csv('/home/nero/phasic_tonic/data/analysis_output/whole_posttrial5/sleep_states_per_trial.csv')

# %%
total_trial_time = df['total_awake_duration']+df['total_sleep_duration']
df['wake_normalized'] = df['total_awake_duration']/total_trial_time
df['nrem_normalized'] = df['total_nrem_duration']/total_trial_time
df['rem_normalized'] = df['total_rem_duration']/total_trial_time
df['nrem_percentage'] = df['total_nrem_duration']/df['total_sleep_duration']
df['rem_percentage'] = df['total_rem_duration']/df['total_sleep_duration']
df
# Out:
#      rat_id  study_day condition  treatment  trial_num  total_sleep_duration  \
# 0         5          8        HC          0        3.0                2552.0
# 1         5          8        HC          0        1.0                 479.0
# 2         5          8        HC          0        2.0                2549.0
# 3         5          8        HC          0        4.0                2190.0
# 4         5          8        HC          0        5.1                2330.0
# ..      ...        ...       ...        ...        ...                   ...
# 858      11          4        OR          4        5.1                2141.0
# 859      11          4        OR          4        5.2                2450.0
# 860      11          4        OR          4        5.3                1264.0
# 861      11          4        OR          4        5.4                 641.0
# 862      11          4        OR          4        3.0                2132.0
#
# ...

# %%
total_trial_time = df2['total_awake_duration']+df2['total_sleep_duration']
df2['wake_normalized'] = df2['total_awake_duration']/total_trial_time
df2['nrem_normalized'] = df2['total_nrem_duration']/total_trial_time
df2['rem_normalized'] = df2['total_rem_duration']/total_trial_time
df2['nrem_percentage'] = df2['total_nrem_duration']/df2['total_sleep_duration']
df2['rem_percentage'] = df2['total_rem_duration']/df2['total_sleep_duration']
df2
# Out:
#      rat_id  study_day condition  treatment  trial_num  total_sleep_duration  \
# 0         5          8        HC          0          3                2552.0
# 1         5          8        HC          0          1                 479.0
# 2         5          8        HC          0          2                2549.0
# 3         5          8        HC          0          4                2190.0
# 4         5          8        HC          0          5                5915.0
# ..      ...        ...       ...        ...        ...                   ...
# 534      11          4        OR          4          1                1435.0
# 535      11          4        OR          4          4                2347.0
# 536      11          4        OR          4          2                2025.0
# 537      11          4        OR          4          5                6498.0
# 538      11          4        OR          4          3                2132.0
#
# ...

# %%
df.to_csv('/home/nero/phasic_tonic/data/analysis_output/segmented_posttrial5/sleep_states_per_trial.csv')
df2.to_csv('/home/nero/phasic_tonic/data/analysis_output/whole_posttrial5/sleep_states_per_trial.csv')
